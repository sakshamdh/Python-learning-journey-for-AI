# %% [markdown]
# __Python Data Classes__
#
# In Python, the dataclass decorator is a feature introduced in Python 3.7 that provides a concise way to define classes primarily intended to store data. It automatically generates several special methods, such as __init__, __repr__ and __eq__, based on the class attributes you define. This simplifies the process of creating and working with data-focused classes.

# %% [markdown]
# __Decorator__
#
# A decorator is a higher-order function that takes another function as input, adds extra functionality, and returns a modified function without altering the original function's code.

# %%
from dataclasses import dataclass

@dataclass
class Person:
    name:str
    age:int
    profession:str

person1=Person('Saksham',22,'AI')
print(person1)
# Out:
# Person(name='Saksham', age=22, profession='AI')

# %% [markdown]
# The @dataclass decorator automatically generates the following methods for you:
#
# 1. __init__(): Initializes the object and assigns the provided values to the attributes.
# 2. __repr__(): Provides a string representation of the object.
# 3. __eq__(): Implements equality comparison between two objects of the class based on their attributes.

# %%
@dataclass
class Person:
    name:str
    age:int
    profession:str='AI'

person1=Person('Saksham',22)
print(person1)
# Out:
# Person(name='Saksham', age=22, profession='AI')

# %%
person1.profession='FullStack Developer'

# %%
print(person1)
# Out:
# Person(name='Saksham', age=22, profession='FullStack Developer')

# %% [markdown]
# __Immutable class__

# %%
@dataclass(frozen=True) # Once the object is initialized the (attribute) values now can't be changed due to frozen command 
class Point:
    x:int
    y:int

point=Point(3,4)
print(point)
# Out:
# Point(x=3, y=4)

# %% [markdown]
# __Inheritance__

# %%
@dataclass
class Person:
    name:str
    age:int

@dataclass
class Employee(Person):
    employee_id:str
    department:str

person=Person('Saksham',22)

employee=Employee('Saksham',22,'123','AI')

# %%
print(employee)
# Out:
# Employee(name='Saksham', age=22, employee_id='123', department='AI')

# %% [markdown]
# __Nested data class__

# %%
@dataclass
class Address:
    street:str
    city:str
    zip_code:str

@dataclass
class Person:
    name:str
    age:int
    address:Address

address=Address('Main Street','Sonipat','131001')
person=Person('Saksham',22,address)

# %%
person
# Out:
# Person(name='Saksham', age=22, address=Address(street='Main Street', city='Sonipat', zip_code='131001'))
