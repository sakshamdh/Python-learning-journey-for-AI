# %% [markdown]
# __Various DataTypes in Python__
#
# Numbers

# %%
1+1
# Out:
# 2

# %%
4*8
# Out:
# 32

# %%
18/3
# Out:
# 6.0

# %%
10**2
# Out:
# 100

# %%
a = 10 * 'Toni'

# %%
type(10)
# Out:
# int

# %%
type('Toni')
# Out:
# str

# %%
type(a)
# Out:
# str

# %%
type(10.0)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %% [markdown]
# Strings

# %%
"Saksham"
# Out:
# 'Saksham'

# %%
type("Saksham")
# Out:
# str

# %% [markdown]
# Variable Assignment

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a = "Saksham"

# %%
type(a)
# Out:
# str

# %%
a = 10
b = 20

# %%
print (a+b)
print (a-b)
print (a*b)
print (a/b)
print (a%b)
print ((a*b) + (a/b))
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 200.5

# %%
print ("Python")
# Out:
# Python

# %%
first_name = 'Saksham'
last_name = 'Dhiman'

# %%
print('My first name is {} and last name is {}'.format(first_name, last_name))
# Out:
# My first name is Saksham and last name is Dhiman

# %%
print (f'My first name is {first_name} and last name is {last_name}')
# Out:
# My first name is Saksham and last name is Dhiman

# %%
print ('My first name is {first} and last name is {last}'.format(last = last_name, first = first_name))
# Out:
# My first name is Saksham and last name is Dhiman

# %%
len('saksham')
# Out:
# 7

# %%
type[int] ([1,2,3,4,8])
# Out:
# list
