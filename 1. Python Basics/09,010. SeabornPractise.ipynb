# %%
import seaborn as sns

# %%
# Practise Homework

iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species             str
# dtype: object

# %%
iris.corr(numeric_only = True)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(numeric_only = True))
# Out:
# <Axes: >

# %%
sns.jointplot(x='petal_width', y='sepal_length', data=iris, kind='reg')

# %%
sns.pairplot(data=iris)

# %%
sns.pairplot(data=iris, hue='species')

# %%
iris['species'].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %%
sns.distplot(iris['petal_length'])
# Out:
# /var/folders/cn/wdc06fpx6v17849rk031ksx00000gn/T/ipykernel_80507/1259963031.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(iris['petal_length'])
# <Axes: xlabel='petal_length', ylabel='Density'>

# %%
sns.countplot(x='petal_width', data=iris, hue='species')
# Out:
# <Axes: xlabel='petal_width', ylabel='count'>

# %%
sns.barplot(x='sepal_length', y='sepal_width', data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.boxplot(x='sepal_length', y='sepal_width', data=iris, palette='rainbow')
# Out:
# /var/folders/cn/wdc06fpx6v17849rk031ksx00000gn/T/ipykernel_80507/2573649246.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='sepal_length', y='sepal_width', data=iris, palette='rainbow')
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.violinplot(x='sepal_length', y='petal_length', data=iris, palette='rainbow')
# Out:
# /var/folders/cn/wdc06fpx6v17849rk031ksx00000gn/T/ipykernel_80507/1102512818.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x='sepal_length', y='petal_length', data=iris, palette='rainbow')
# <Axes: xlabel='sepal_length', ylabel='petal_length'>
