# %% [markdown]
# __Vulture Library__
#
# It finds unused codes and dead codes

# %%
# !pip install Vulture
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os

# %%
import pandas as pd

# %%
import numpy as np

# %%
class Greeter:
    def greet(self):
        print("Hi")

# %%
def hello_world():
    var = 123
    var1 = 1223-23
    var4 = 20
    message = "Hello, world!"
    greeter = Greeter()
    greet_func = getattr(greeter, "greet")
    greet_func()

# %%
if __name__ == "__main__":
    hello_world()
# Out:
# Hi

# %% [markdown]
# Can be printed in .py file only

# %%
# !jupyter nbconvert --to script "40. Vulture Library.ipynb"
# !vulture "40. Vulture Library.ipynb"
# Out:
# [NbConvertApp] Converting notebook 40. Vulture Library.ipynb to script
# [NbConvertApp] Writing 738 bytes to 40. Vulture Library.py
