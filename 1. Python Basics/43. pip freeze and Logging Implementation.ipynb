# %% [markdown]
# __pip freeze__

# %% [markdown]
# pip freeze is a command that shows all Python packages installed in your current environment along with their exact versions.

# %%
pip freeze
# Out:
# appnope==0.1.4
# asttokens==3.0.1
# attrs==26.1.0
# beautifulsoup4==4.14.3
# certifi==2026.4.22
# charset-normalizer==3.4.7
# click==8.4.1
# comm==0.2.3
# contourpy==1.3.3
# cycler==0.12.1
# debugpy==1.8.20
# decorator==5.2.1
# et_xmlfile==2.0.0
# executing==2.2.1
# filelock==3.29.0
# fonttools==4.62.1
# fsspec==2026.4.0
# html5lib==1.1
# idna==3.13
# ipykernel==7.2.0
# ipython==9.11.0
# ipython_pygments_lexers==1.1.1
# jedi==0.19.2
# joblib==1.5.3
# jsonschema==4.26.0
# jsonschema-specifications==2025.9.1
# jupyter_client==8.8.0
# jupyter_core==5.9.1
# kiwisolver==1.5.0
# lxml==6.1.0
# matplotlib==3.10.9
# matplotlib-inline==0.2.1
# modin==0.37.1
# msgpack==1.1.2
# nest-asyncio==1.6.0
# numpy==2.4.4
# openpyxl==3.1.5
# packaging==26.0
# pandas==2.3.3
# parso==0.8.6
# pexpect==4.9.0
# pillow==12.2.0
# platformdirs==4.9.4
# prompt_toolkit==3.0.52
# protobuf==7.35.0
# psutil==7.2.2
# ptyprocess==0.7.0
# pure_eval==0.2.3
# pyarrow==24.0.0
# Pygments==2.19.2
# pyparsing==3.3.2
# ...

# %% [markdown]
# __Logging Implementation__

# %%
import logging

logging.basicConfig(filename = 'Saksham.txt',
                    filemode = 'a',
                    format = '%(asctime)s %(levelname)s-%(message)s',
                    datefmt = '%Y-%m-%d %H:%M:%S')

for i in range(0,15):
    if(i%2==0):
        logging.warning('Log Warning Message')
    elif(i%3==0):
        logging.critical('Log Critical Message')
    else:
        logging.error('Log Error Message')

# %%
i = 10
try:
    i=i/0
except:
    logging.error("Division by 0 error")
