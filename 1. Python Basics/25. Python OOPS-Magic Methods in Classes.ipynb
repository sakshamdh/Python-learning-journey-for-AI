# %% [markdown]
# __Python OOPS-Magic Methods in Classes__

# %%
class Car():
    def __new__(self,windows,doors,enginetype):
        print("The object has started getting initialized")
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    def __str__(self):
        return "The object has been initialized"
    def __sizeof__(self):
        return "This desplays size of the object"
    def drive(self):
        print("The Person drive the car")

# %%
c=Car(4,5,'Diesel')
# Out:
# The object has started getting initialized

# %%
c

# %%
print(c)
# Out:
# None

# %%
c.__sizeof__()
# Out:
# 16

# %%
dir(c)
# Out:
# ['__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__']

# %% [markdown]
# __All these are Magic Methods in Class__ which are present above
