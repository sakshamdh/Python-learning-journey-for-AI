# %% [markdown]
# __!! Important !!__
#
# __Python is a slow programming language because it is a interpreted programming language as compared to JAVA and C++.__
#
# __These other two languages use this just-in-time compiler wherein they convert the entire code into the machine level code, whereas in the case of python, it gets directly executed and this conversion is not there and because of this python is really slow when compared to JAVA and C++__

# %% [markdown]
# __Quick Guide to Numba__

# %% [markdown]
# Numba is a just-in-time compiler for Python that works best on code that uses NumPy arrays and functions, and loops. The most common way to use Numba is through its collection of decorators that can be applied to your functions to instruct Numba to compile them. When a call is made to a Numba decorated function it is compiled to machine code "just-in-time" for execution and all or part of your code can subsequently run at native machine code speed!

# %%
# !pip install numba
# Out:
# ...
#
# [notice] A new release of pip is available: 26.1.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
from numba import jit
import numpy as np
import time

x = np.arange(1000).reshape(100,10)

@jit(nopython=True) # This is a decorator
def go_fast(a): # Function is compiled and runs in machine code 
    trace = 0.0
    for i in range(a.shape[0]):
        trace += np.tanh(a[i, i])
    return a + trace

# DO NOT REPORT THIS... COMPILATION TIME IS INCLUDED IN THE EXECUTION TIME!
start = time.time()
go_fast(x)
end = time.time()
print("Elapsed (with compilation) = %s" % (end-start))

# NOW THE FUNCTION IS COMPILED, RE-TIME IT EXECUTING FROM CACHE
start = time.time()
go_fast(x)
end = time.time()
print("Elapsed (after compilation) = %s" % (end-start))
# Out:
# Elapsed (with compilation) = 0.12168693542480469
# Elapsed (after compilation) = 4.1961669921875e-05

# %% [markdown]
# 8.606910705566406e-05 = 8.606910705566406 × 10^-5 = 0.00008606910705566406 < 0
