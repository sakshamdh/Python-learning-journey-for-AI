# %% [markdown]
# __is__ vs __==__
#
# == is a comparison operator used to check whether two values are equal.
#
# __whereas__
#
# is → compares MEMORY LOCATION (object identity). Checks whether both variables point to the exact same object in memory.

# %%
lst1 = ['Saksham','Saksham1','Saksham2']
lst2 = ['Saksham','Saksham1','Saksham2']
lst1 == lst2
# Out:
# True

# %%
a = 'Saksham'
b = 'Saksham'
a==b
# Out:
# True

# %%
lst1 = ['Saksham','Saksham1','Saksham2']
lst2 = ['Saksham','Saksham1','Saksham2']
lst1 is lst2
# Out:
# False

# %%
lst1 = ['Saksham','Saksham1','Saksham2']
lst2 = lst1
lst1 is lst2
# Out:
# True

# %%
lst2 is lst1
# Out:
# True

# %%
lst2[0]='Saksham2'

# %%
lst2
# Out:
# ['Saksham2', 'Saksham1', 'Saksham2']

# %%
lst1
# Out:
# ['Saksham2', 'Saksham1', 'Saksham2']

# %% [markdown]
# __Deep copy__
#
# It will make a different memory location that's why you see False

# %%
lst1 = ['Saksham','Saksham1','Saksham2']
lst2 = lst1.copy()
lst1 is lst2
# Out:
# False

# %%
lst2[0]='Saksham2'

# %%
lst2
# Out:
# ['Saksham2', 'Saksham1', 'Saksham2']

# %%
lst1
# Out:
# ['Saksham', 'Saksham1', 'Saksham2']
