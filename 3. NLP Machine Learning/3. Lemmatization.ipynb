# %% [markdown]
# __Wordnet Lemmatizer__
#
# Lemmatization technique is like stemming. The output we will get after lemmatization is called 'lemma', which is a root word rather than root stem, the output of stemming. After lemmatization, we will be getting a valid word that means the same thing.
#
# NLTK provides WordNetLemmatizer class which is a thin wrapper around the wordnet corpus. This class uses morphy() function to the WordNet CorpusReader class to find a lemma.

# %% [markdown]
# Time taken by WordNet Lemmatizer is more than stemming as it compares with wordnet corpus..

# %% [markdown]
# __Best for Q&A, chatbots, text summarization__

# %%
import nltk

nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/manojkumar/nltk_data...
# True

# %%
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

# %%
'''
POS - (post tag)
Noun - n
verb - v
adjective - a
adverb - r
'''

lemmatizer.lemmatize("going", pos='v') # Go is a verb so pos as v will work best
# Out:
# 'go'

# %%
lemmatizer.lemmatize("going", pos='a')
# Out:
# 'going'

# %%
lemmatizer.lemmatize("going", pos='r')
# Out:
# 'going'

# %%
words = ["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# for noun is doesn't really changes much because noun is refered for names and like Saksham Dhiman it won't change anything in it

# %%
for word in words:
    print(word+' ---› '+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating ---› eat
# eats ---› eat
# eaten ---› eat
# writing ---› write
# writes ---› write
# programming ---› program
# programs ---› program
# history ---› history
# finally ---› finally
# finalized ---› finalize

# %%
lemmatizer.lemmatize("goes",pos='v')
# Out:
# 'go'
